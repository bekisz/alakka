# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

url="https://raw.githubusercontent.com/bekisz/alakka/master/output/GaltonWatson_seedSurvivalChance.csv/part-00000-13089a2a-5658-412f-af50-8f54a8d009b8-c000.csv"
df=pd.read_csv(url, sep=',',header=0)
# df=pd.read_csv('/Users/szabolcsbeki/Documents/GitHub/alakka/output/GaltonWatson_seedSurvivalChance.csv/part-00000-13089a2a-5658-412f-af50-8f54a8d009b8-c000.csv', sep=',',header=0)

df1000= df[df['maxPopulation'] == 1000]


fig = plt.figure()
fig.subplots_adjust(top=0.8)
ax1 = fig.add_subplot(211)
ax1.set_ylabel('Probability')
ax1.set_xlabel('Lambda - Average number of children')
ax1.set_title('a sine wave')

ax1.plt.plot(df1000['lambda'], df1000["seedSurvivalChance"], label='Probability of Eternal Survival', color='red', linewidth=3)
ax1.plot(df1000['lambda'], df1000["seedSurvivalChance"]+df1000['error'], label='99% Confidence Interval - High', color='coral', linewidth=1)
ax1.plot(df1000['lambda'], df1000["seedSurvivalChance"]-df1000['error'], label='99% Confidence Interval - Low', color='coral', linewidth=1)
ax1.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-67-74c026226707> in <module>
#       4
#       5 url="https://raw.githubusercontent.com/bekisz/alakka/master/output/GaltonWatson_seedSurvivalChance.csv/part-00000-13089a2a-5658-412f-af50-8f54a8d009b8-c000.csv"
# ----> 6 df=pd.read_csv(url, sep=',',header=0)
#       7 # df=pd.read_csv('/Users/szabolcsbeki/Documents/GitHub/alakka/output/GaltonWatson_seedSurvivalChance.csv/part-00000-13089a2a-5658-412f-af50-8f54a8d009b8-c000.csv', sep=',',header=0)
#       8
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#url="https://raw.githubusercontent.com/bekisz/alakka/master/output/GaltonWatson_seedSurvivalChance.csv/part-00000-13089a2a-5658-412f-af50-8f54a8d009b8-c000.csv"
#df=pd.read_csv(url, sep=',',header=0)
dfPop=pd.read_csv('/Users/szabolcsbeki/Documents/GitHub/alakka/output/GaltonWatson_seedSurvivalChanceByTurn.csv/part-00000-3f97ae10-d9cf-45ea-91a7-ab0125bec1ef-c000.csv', sep=',',header=0)
dfPop=dfPop[dfPop['lambda'] == 1.2]

plt.plot(dfPop['turn'], dfPop["seedPopulation"], label='Average of Seed Population by Generation', color='blue', linewidth=3)
plt.plot(dfPop['turn'], dfPop["seedPopulation"]+dfPop['error'], label='99% Confidence Interval - High', color='lightblue', linewidth=1)
plt.plot(dfPop['turn'], dfPop["seedPopulation"]-dfPop['error'], label='99% Confidence Interval - Low', color='lightblue', linewidth=1)
plt.legend()
plt.show()
